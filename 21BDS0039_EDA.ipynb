# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("HepatitisCdata.csv")
print(df.head())
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
df.shape
# Out:
# (615, 14)

# %%
df.Sex.value_counts()
df.Category.value_counts()
# Out:
# Category
# 0=Blood Donor             526
# 3=Cirrhosis                24
# 1=Hepatitis                20
# 2=Fibrosis                 12
# 0s=suspect Blood Donor      7
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  615 non-null    int64
#  1   Category    615 non-null    object
#  2   Age         615 non-null    int64
#  3   Sex         615 non-null    object
#  4   ALB         614 non-null    float64
#  5   ALP         597 non-null    float64
#  6   ALT         614 non-null    float64
#  7   AST         615 non-null    float64
#  8   BIL         615 non-null    float64
#  9   CHE         615 non-null    float64
#  10  CHOL        605 non-null    float64
#  11  CREA        615 non-null    float64
#  12  GGT         615 non-null    float64
#  13  PROT        614 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 67.4+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            1
# ALP           18
# ALT            1
# AST            0
# BIL            0
# CHE            0
# CHOL          10
# CREA           0
# GGT            0
# PROT           1
# dtype: int64

# %%
df.dropna()
# Out:
#      Unnamed: 0       Category  Age Sex   ALB    ALP   ALT    AST   BIL  \
# 0             1  0=Blood Donor   32   m  38.5   52.5   7.7   22.1   7.5
# 1             2  0=Blood Donor   32   m  38.5   70.3  18.0   24.7   3.9
# 2             3  0=Blood Donor   32   m  46.9   74.7  36.2   52.6   6.1
# 3             4  0=Blood Donor   32   m  43.2   52.0  30.6   22.6  18.9
# 4             5  0=Blood Donor   32   m  39.2   74.1  32.6   24.8   9.6
# ..          ...            ...  ...  ..   ...    ...   ...    ...   ...
# 608         609    3=Cirrhosis   58   f  34.0   46.4  15.0  150.0   8.0
# 609         610    3=Cirrhosis   59   f  39.0   51.3  19.6  285.8  40.0
# 610         611    3=Cirrhosis   62   f  32.0  416.6   5.9  110.3  50.0
# 611         612    3=Cirrhosis   64   f  24.0  102.8   2.9   44.4  20.0
# 612         613    3=Cirrhosis   64   f  29.0   87.3   3.5   99.0  48.0
#
#        CHE  CHOL   CREA    GGT  PROT
# 0     6.93  3.23  106.0   12.1  69.0
# 1    11.17  4.80   74.0   15.6  76.5
# 2     8.84  5.20   86.0   33.2  79.3
# 3     7.33  4.74   80.0   33.8  75.7
# 4     9.15  4.32   76.0   29.9  68.7
# ..     ...   ...    ...    ...   ...
# 608   6.26  3.98   56.0   49.7  80.6
# 609   5.77  4.51  136.1  101.1  70.5
# 610   5.57  6.30   55.7  650.9  68.5
# 611   1.54  3.02   63.0   35.9  71.3
# 612   1.66  3.63   66.7   64.2  82.0
#
# [589 rows x 14 columns]

# %%
print(df.describe())
print( df.isnull().sum())
# Out:
#        Unnamed: 0         Age         ALB         ALP         ALT         AST  \
# count  589.000000  589.000000  589.000000  589.000000  589.000000  589.000000
# mean   298.648557   47.417657   41.624278   68.123090   26.575382   33.772835
# std    174.142507    9.931334    5.761794   25.921072   20.863120   32.866871
# min      1.000000   23.000000   14.900000   11.300000    0.900000   10.600000
# 25%    149.000000   39.000000   38.800000   52.500000   16.400000   21.500000
# 50%    296.000000   47.000000   41.900000   66.200000   22.700000   25.700000
# 75%    448.000000   54.000000   45.100000   79.900000   31.900000   31.700000
# max    613.000000   77.000000   82.200000  416.600000  325.300000  324.000000
#
#               BIL         CHE        CHOL         CREA         GGT        PROT
# count  589.000000  589.000000  589.000000   589.000000  589.000000  589.000000
# mean    11.018166    8.203633    5.391341    81.669100   38.198472   71.890153
# std     17.406572    2.191073    1.128954    50.696991   54.302407    5.348883
# min      0.800000    1.420000    1.430000     8.000000    4.500000   44.800000
# 25%      5.200000    6.930000    4.620000    68.000000   15.600000   69.300000
# 50%      7.100000    8.260000    5.310000    77.000000   22.800000   72.100000
# 75%     11.000000    9.570000    6.080000    89.000000   37.600000   75.200000
# max    209.000000   16.410000    9.670000  1079.100000  650.900000   86.500000
# Unnamed: 0    0
# Category      0
# Age           0
# Sex           0
# ALB           0
# ALP           0
# ALT           0
# AST           0
# BIL           0
# CHE           0
# CHOL          0
# CREA          0
# GGT           0
# PROT          0
# dtype: int64

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (589, 14)

# %%
print("Mean of ALT", df['ALT'].mean())
print("Median of ALT", df['ALT'].median())
print("Mode of ALT", df['ALT'].mode())
# Out:
# Mean of ALT 26.575382003395585
# Median of ALT 22.7
# Mode of ALT 0    16.6
# Name: ALT, dtype: float64

# %%
sns.FacetGrid(df).map(sns.histplot, "ALT").add_legend()
plt.show()

# %%
sns.histplot(df['ALT'], kde=True)
plt.title('Distribution of ALT')
plt.show()

# %%
sns.boxplot(x="ALT", data=df)
plt.title('Boxplot of ALT')
plt.show()

# %%
plt.scatter(df["Age"], df["ALT"])
plt.title('Scatter plot of Age vs ALT')
plt.xlabel('Age')
plt.ylabel('ALT')
plt.show()

# %%
sns.pairplot(df, vars=['Age', 'ALT', 'AST'], kind="reg")
plt.show()

# %%
import numpy as np
corr = stats.pearsonr(df["Age"], df["ALT"])
print("p-value:\t", corr[1])
print("Correlation coefficient:\t", corr[0])
# Out:
# p-value:	 0.32556987395894527
# Correlation coefficient:	 -0.04057646812102197

# %%
df_numeric = df.select_dtypes(include=[np.number])
correlation = df_numeric.corr(method='pearson')
print(correlation)

sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
#             Unnamed: 0       Age       ALB       ALP       ALT       AST  \
# Unnamed: 0    1.000000  0.443058 -0.315205  0.017944 -0.200233  0.303603
# Age           0.443058  1.000000 -0.191094  0.177720 -0.040576  0.072739
# ALB          -0.315205 -0.191094  1.000000 -0.146120  0.039497 -0.177609
# ALP           0.017944  0.177720 -0.146120  1.000000  0.221603  0.067024
# ALT          -0.200233 -0.040576  0.039497  0.221603  1.000000  0.198658
# AST           0.303603  0.072739 -0.177609  0.067024  0.198658  1.000000
# BIL           0.176511  0.039655 -0.169597  0.058372 -0.106797  0.309580
# CHE          -0.278535 -0.075863  0.360919  0.029482  0.224344 -0.197270
# CHOL         -0.057947  0.124742  0.210420  0.125900  0.149997 -0.201213
# CREA         -0.020163 -0.025142  0.001433  0.153909 -0.036106 -0.017948
# GGT           0.221463  0.143379 -0.147598  0.461300  0.219707  0.477774
# PROT         -0.166482 -0.159760  0.570726 -0.063085  0.016786  0.017404
#
#                  BIL       CHE      CHOL      CREA       GGT      PROT
# Unnamed: 0  0.176511 -0.278535 -0.057947 -0.020163  0.221463 -0.166482
# Age         0.039655 -0.075863  0.124742 -0.025142  0.143379 -0.159760
# ALB        -0.169597  0.360919  0.210420  0.001433 -0.147598  0.570726
# ALP         0.058372  0.029482  0.125900  0.153909  0.461300 -0.063085
# ALT        -0.106797  0.224344  0.149997 -0.036106  0.219707  0.016786
# AST         0.309580 -0.197270 -0.201213 -0.017948  0.477774  0.017404
# BIL         1.000000 -0.320713 -0.181570  0.019910  0.210567 -0.052575
# CHE        -0.320713  1.000000  0.428018 -0.012120 -0.095716  0.306288
# CHOL       -0.181570  0.428018  1.000000 -0.051464  0.008823  0.245050
# CREA        0.019910 -0.012120 -0.051464  1.000000  0.125353 -0.030111
# GGT         0.210567 -0.095716  0.008823  0.125353  1.000000 -0.037127
# PROT       -0.052575  0.306288  0.245050 -0.030111 -0.037127  1.000000
